# %% [markdown]
# Testing CNN method from https://wandb.ai/mostafaibrahim17/ml-articles/reports/An-Introduction-to-Audio-Classification-with-Keras--Vmlldzo0MDQzNDUy#:~:text=%EF%BB%BFKeras%20is%20a%20go,both%20beginners%20and%20advanced%20users.
#
# https://keras.io/guides/sequential_model/

# %%
import os
import numpy as np
import pandas as pd
import librosa
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from keras.utils import to_categorical
from keras.models import Sequential
from keras import layers # example functions: Dense, Dropout, Activation, Flatten, Conv1D, MaxPooling1D
from keras import Input
import matplotlib.pyplot as plt
import time
import pickle

# %%
# %run FeedingData.ipynb
# read Calvin's function files so we can call those functions from this notebook
# list of functions: 
# mfcc_(song, n=20)
# mfcc_cut(song, n=20, cutoff = 800)
# LFCC(song, n=20)
# LFCC_no_low(song, n=20, cutoff = 800)
# LFCC_no_low_clean(song, n=20, cutoff = 800)
# mfcc_cut_cleaned(song, n=20, cutoff = 800)
# main_freq(song, cutoff = 800)

# %% [markdown]
# song, sr = librosa.load('E:\chirpfiles\\no_voice_files\\119063.wav')
# main_freq(song,n=40).shape

# %%
def get_data(audio_path, meta_file, load_length, get_feature_function):
    songs_matrix = []
    songs_id = []
    df = pd.read_csv(meta_file)
    id_list = df.cat_num

    for name in id_list:
        filepath = os.path.join(audio_path, str(name)+'.wav')
        # skipping files that are less than 250 ~ 5sec long
        # this is to make sure we have enough length for sampling fft time intervals
        if os.path.getsize(filepath) < load_length*50000:
            continue
        # ============ load the data and get matrix ============
        # make sure that the size of the feature matrix is the same for all files
        song, sr = librosa.load(filepath, duration=load_length)
        features = get_feature_function(song, n = 40)
        songs_matrix.append(features)
        songs_id.append(name)
    return np.array(songs_matrix), songs_id

# %%
def get_labels(numbers, meta_file, label_name):
    # take in list of data id numbers and output their labels in label_name calssification
    df = pd.read_csv(meta_file)
    labels = []
    for num in numbers:
        labels.append(df[label_name].loc[df.cat_num == float(num)].item())
    return np.array(labels)

# %%
# for converting strings of label from one division to another, e.g. fam/subfam to critter name
def convert_labels(labels, meta_file, from_division, to_division):
    # find label in labels in meta_file under column from_division
    # append as key in dictionary lookup_table, append as value the corresponding label in to_division

    df = pd.read_csv(meta_file, usecols=[from_division, to_division])
    lookup_table = dict() # look up table for new label
    for label in labels:
        if label in lookup_table.keys():
            continue
        idx = df.loc[df[from_division]==label].index[0]
        lookup_table[label] = df[to_division][idx]
    return [lookup_table[label] for label in labels]

# %%
def remove_small_class(songs_matrix, songs_label, threshold):
    df_class = pd.DataFrame(np.unique(songs_label, return_counts=True)).T
    print('Data read:\n', df_class)
    # remove classes with too few data points
    small_class_list = []
    for row in range(len(df_class)):
        if df_class[1].iloc[row] < threshold:
            small_class_list.append(df_class[0].iloc[row].item())
    print('Removing classes:\n',small_class_list)
    delete_list = []
    for small_class in small_class_list:
        delete_list += list(np.where(songs_label==small_class)[0])

    short_label = np.delete(songs_label, delete_list)
    short_matrix = np.delete(songs_matrix, delete_list, 0)
    # double check data after deleting
    print('Reduced data:\n', pd.DataFrame(np.unique(short_label, return_counts=True)).T)
    return short_matrix, short_label

# %%
def get_var_name(var):
    for name, value in globals().items():
        if value is var:
            return name

# %% [markdown]
# ## run model loop over all functions

# %%
# load all audio in audio_path
# convert to matrix, save in np array, 
# load the corresponding label_name from lable_filename, save in another np array

list_of_fun = [mfcc_cut, LFCC, LFCC_no_low, LFCC_no_low_clean, mfcc_cut_cleaned]

audio_path = 'E:\chirpfiles\\no_voice_files'
meta_file = 'MLNS_05282024.csv'

max_time = 5 # cut off time for loading, in sec

for i in range(5):
    get_feature_function = list_of_fun[i]
    songs_matrix, songs_id = get_data(audio_path, meta_file, max_time, get_feature_function)
    songs_label_critter = get_labels(songs_id, meta_file, 'critter_name')
    #songs_label_fam = get_labels(songs_id, meta_file, 'fam_or_subfam')

    le = LabelEncoder()
    songs_label_num = le.fit_transform(songs_label_critter)
    songs_label_onehot = to_categorical(songs_label_num) # required output format by cnn
    
    #np.save('songs_matrix_mfcc_5sec.npy', songs_matrix)
    #np.save('songs_label_critter_5sec.npy', songs_label_critter)
    #np.save('songs_label_fam_5sec.npy', songs_label_fam)
    #np.save('songs_id_5sec.npy', songs_id)

    # rename data/label variable name so that we don't need to change them in the model block
    data_matrix = songs_matrix
    data_label = songs_label_onehot
    print(data_matrix.shape, data_label.shape)
    X_train, X_test, y_train, y_test = train_test_split(data_matrix, data_label, 
                                                        test_size = .2, random_state = 17)
    # to use 2d convolution, keras model expects 4d input shape
    X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],X_train.shape[2],1))
    X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],X_test.shape[2],1))
    print('Train test split train shape: ', X_train.shape)

    X_tt, X_val, y_tt, y_val = train_test_split(X_train, y_train, test_size = .2, random_state = 17)
    print('Train validation split train shape: ', X_tt.shape)

    # make model 
    input_shape =  (X_tt.shape[1], X_tt.shape[2],1,) # first dimension of train data is n_datapoints
    model = Sequential() 
    model.add(Input(input_shape))
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2,2), strides=2))
    model.add(layers.Dropout(0.2))
#    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
#    model.add(layers.MaxPooling2D((2,2), strides=2))
#    model.add(layers.Dropout(0.2))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(len(le.classes_), activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    #model.summary()

    # train model
    start = time.time()
    epochs = 50
    history = model.fit(X_tt, y_tt, epochs=epochs, batch_size=64, validation_data=(X_val, y_val))
    end = time.time()
    print('time training: ', end - start)

    pkl_name = 'hist_'+ get_var_name(list_of_fun[i]) +'_batch64_onehiddenlayer_5sec_critter.pkl'
    with open(pkl_name, 'wb') as f:  # Python 3: open(..., 'wb')
        pickle.dump(history, f)

    # Getting back the objects:
    #with open('hist_batch64_onehiddenlayer_5sec_critter.pkl') as f:  # Python 3: open(..., 'rb')
    #    obj0, obj1, obj2 = pickle.load(f)
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_21748\2796635937.py:4: DtypeWarning: Columns (25,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(meta_file)
# C:\Users\sarah\AppData\Local\Temp\ipykernel_21748\1885170622.py:3: DtypeWarning: Columns (25,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(meta_file)
# (5645, 40, 216) (5645, 3)
# Train test split train shape:  (4516, 40, 216, 1)
# Train validation split train shape:  (3612, 40, 216, 1)
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 32s 435ms/step - accuracy: 0.6502 - loss: 69.7659 - val_accuracy: 0.7378 - val_loss: 1.8452
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 23s 398ms/step - accuracy: 0.7021 - loss: 1.1298 - val_accuracy: 0.6582 - val_loss: 0.5437
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s
# Epoch 22/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9115 - loss: 0.2053 - val_accuracy: 0.8883 - val_loss: 0.4484
# Epoch 23/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9229 - loss: 0.1983 - val_accuracy: 0.8794 - val_loss: 0.5032
# Epoch 24/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.9109 - loss: 0.2048 - val_accuracy: 0.8662 - val_loss: 0.4957
# Epoch 25/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9280 - loss: 0.1949 - val_accuracy: 0.8905 - val_loss: 0.4502
# Epoch 26/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.9167 - loss: 0.2061 - val_accuracy: 0.8894 - val_loss: 0.3885
# Epoch 27/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9203 - loss: 0.1925 - val_accuracy: 0.8827 - val_loss: 0.3878
# Epoch 28/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9085 - loss: 0.2116 - val_accuracy: 0.8440 - val_loss: 0.5218
# Epoch 29/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.9209 - loss: 0.1865 - val_accuracy: 0.8761 - val_loss: 0.5631
# Epoch 30/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.8924 - loss: 0.2273 - val_accuracy: 0.8838 - val_loss: 0.4326
# Epoch 31/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9205 - loss: 0.1852 - val_accuracy: 0.8750 - val_loss: 0.4120
# Epoch 32/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9137 - loss: 0.1978 - val_accuracy: 0.8761 - val_loss: 0.3962
# Epoch 33/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9016 - loss: 0.2248 - val_accuracy: 0.8330 - val_loss: 1.0391
# Epoch 34/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.9148 - loss: 0.2150 - val_accuracy: 0.8429 - val_loss: 0.4504
# Epoch 35/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9145 - loss: 0.2081 - val_accuracy: 0.8861 - val_loss: 0.4985
# Epoch 36/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.9246 - loss: 0.1811 - val_accuracy: 0.8827 - val_loss: 0.4436
# Epoch 37/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9161 - loss: 0.1908 - val_accuracy: 0.8916 - val_loss: 0.6193
# Epoch 38/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9218 - loss: 0.1814 - val_accuracy: 0.8750 - val_loss: 0.6147
# Epoch 39/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9191 - loss: 0.1780 - val_accuracy: 0.8684 - val_loss: 0.4462
# Epoch 40/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9140 - loss: 0.1953 - val_accuracy: 0.8916 - val_loss: 0.5157
# Epoch 41/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9281 - loss: 0.1736 - val_accuracy: 0.8816 - val_loss: 0.4845
# Epoch 42/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9208 - loss: 0.1761 - val_accuracy: 0.8728 - val_loss: 0.6060
# Epoch 43/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9207 - loss: 0.1826 - val_accuracy: 0.8905 - val_loss: 0.4535
# Epoch 44/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.9212 - loss: 0.1714 - val_accuracy: 0.8883 - val_loss: 0.4234
# Epoch 45/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.9212 - loss: 0.1856 - val_accuracy: 0.8838 - val_loss: 0.5033
# Epoch 46/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9106 - loss: 0.1977 - val_accuracy: 0.8551 - val_loss: 0.4855
# Epoch 47/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9116 - loss: 0.1904 - val_accuracy: 0.8429 - val_loss: 0.8564
# Epoch 48/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9171 - loss: 0.2014 - val_accuracy: 0.8827 - val_loss: 0.5706
# Epoch 49/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.9186 - loss: 0.1822 - val_accuracy: 0.8772 - val_loss: 0.6325
# Epoch 50/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9231 - loss: 0.1703 - val_accuracy: 0.8684 - val_loss: 0.5346
# time training:  601.2710444927216

# %%
history_dict = h2.history
plt.figure(figsize = (4, 3))
plt.scatter(range(1,epochs+1), history_dict['accuracy'], label = "Training Accuracy")
plt.scatter(range(1,epochs+1), history_dict['val_accuracy'], label = "Validation Set Accuracy")

plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.legend(fontsize=12)

plt.show()

plt.figure(figsize = (4, 3))

plt.scatter(range(1,epochs+1), history_dict['loss'], label = "Training Loss")
plt.scatter(range(1,epochs+1), history_dict['val_loss'], label = "Validation Set Loss")

plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss Function Value", fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.legend(fontsize=12)

plt.show()

# %% [markdown]
# # vvv
# ### Report accuracy on validation set

# %%
predicted_vector = model.predict(X_val)
predicted_class_index = np.argmax(predicted_vector, axis=-1)
pred_class = le.inverse_transform(predicted_class_index)
true_class_idx = np.where(y_val.astype(int))[1]
true_class = le.inverse_transform(true_class_idx)
print(true_class)
conf_mat = confusion_matrix(true_class, pred_class)
print(pd.DataFrame(conf_mat))#,
#                 columns = ['Predicted 0', 'Predicted 1', 'Predicted 2', 'Predicted 3'],
#                 index = ['Actual 0', 'Actual 1', 'Actual 2', 'Actual 3'])
accuracy = np.diagonal(conf_mat).sum()/np.sum(conf_mat)
print('accuracy =', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# ['cricket' 'kaydid' 'cricket' 'cricket' 'kaydid' 'kaydid' 'cricket'
#  'kaydid' 'kaydid' 'kaydid' 'cricket' 'cricket' 'cricket']
#    0  1
# 0  7  0
# 1  4  2
# accuracy = 0.6923076923076923

# %%
## to shorte list of classes after fitting on long list, use the class converter. 
true_class_short = convert_labels(true_class, meta_file, label_name, 'critter_name')
pred_class_short = convert_labels(pred_class, meta_file, label_name, 'critter_name')
conf_mat = confusion_matrix(true_class_short, pred_class_short)
print(pd.DataFrame(conf_mat))
accuracy = np.diagonal(conf_mat).sum()/np.sum(conf_mat)
print('accuracy =', accuracy)
# Out:
#    0  1
# 0  7  0
# 1  4  2
# accuracy = 0.6923076923076923

# %% [markdown]
# # vvv
# ### Forbidden test set block

# %%
predicted_vector = model.predict(X_test)
predicted_class_index = np.argmax(predicted_vector, axis=-1)

pred_class = le.inverse_transform(predicted_class_index)

true_class_idx = np.where(y_test.astype(int))[1]
true_class = le.inverse_transform(true_class_idx)
print(true_class)

conf_mat = confusion_matrix(true_class, pred_class)
print(pd.DataFrame(conf_mat))#,
#                 columns = ['Predicted 0', 'Predicted 1', 'Predicted 2', 'Predicted 3'],
#                 index = ['Actual 0', 'Actual 1', 'Actual 2', 'Actual 3'])
accuracy = np.diagonal(conf_mat).sum()/np.sum(conf_mat)
print('accuracy =', accuracy)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
## to shorte list of classes after fitting on long list, use the class converter. 
true_class_short = convert_labels(true_class, meta_file, label_name, 'critter_name')
pred_class_short = convert_labels(pred_class, meta_file, label_name, 'critter_name')

conf_mat = confusion_matrix(true_class_short, pred_class_short)
print(pd.DataFrame(conf_mat))
accuracy = np.diagonal(conf_mat).sum()/np.sum(conf_mat)
print('accuracy =', accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 ## to shorte list of classes after fitting on long list, use the class converter.
# ----> 2 true_class_short = convert_labels(true_class, meta_file, label_name, 'critter_name')
#       3 pred_class_short = convert_labels(pred_class, meta_file, label_name, 'critter_name')
#
# Cell In[69], line 7, in convert_labels(labels, meta_file, from_division, to_division)
#       2 def convert_labels(labels, meta_file, from_division, to_division):
#       3     # find label in labels in meta_file under column from_division
#       4     # append as key in dictionary lookup_table
#       5     # append as value the correspondign label in to_division
# ----> 7     df = pd.read_csv(meta_file, usecols=[from_division, to_divison])
#       8     lookup_table = dict() # look up table for new label
#       9     for label in labels:
#
# NameError: name 'to_divison' is not defined
